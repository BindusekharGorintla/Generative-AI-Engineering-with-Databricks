# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# ## Get Started with AI Agents on Databricks
#
# This course is an introduction to AI agents, their role in modern AI applications, and how to build AI agent applications on the Databricks platform. You'll learn about the principles of AI agents, how they differ from traditional AI systems, and explore their key components. Through interactive demos and hands-on labs, you'll see how to build, deploy, and evaluate AI agents on Databricks using Mosaic AI and Agent Bricks. By the end of this course, you'll understand how to create and deploy AI agents using the Databricks Data Intelligence Platform.
#
# <br/>
#
# ---
#
# ## Prerequisites
#
# This content is designed for participants who possess the following skills and experience:
#
# - **Platform Proficiency**
#   - Python programming
#   - Foundational Knowledge of Databricks Platform, including Unity Catalog
#   - Familiarity with ML/AI concepts
# <br/>
#
# ---
#
# ## Course Agenda
#
# The following modules are part of the **Get Started with AI Agents on Databricks** course by **Databricks Academy**.
#
# | Module | Content |
# |:----:|-------|
# | **Module 1 – Introduction to AI Agents** | **Lecture -** What is an AI Agent <br/>**Lecture -** AI Agent Patterns <br/>**Lecture -** AI Agent Components <br/>**Lecture -** Common Agentic AI Use-Cases <br/>|
# | **[Module 2 – Building AI Agents on Databricks]($./M02 - Building AI Agents on Databricks/)** | **Lecture -** The Challenges with Agents in Production<br/>**Lecture -** Overview of Mosaic AI for Agent Development<br/>**Lecture -** Custom Agent Development with Mosaic AI<br/>[**Demo:** Get Started with AI Agent on Databricks]($./M02 - Building AI Agents on Databricks/2.1 - Get Started with AI Agent on Databricks)<br/>[**Demo:** Build Agent Tools and Prototype with AI Playground]($./M02 - Building AI Agents on Databricks/2.2 - Build Agent Tools and Prototype with AI Playground)<br/>
# | **[Module 3 – Agent Evaluation and Deployment with Mosaic AI]($./M03 - Agent Evaluation and Deployment with Mosaic AI/)** | **Lecture -** The Agent Evaluation and MLflow</br>[**Demo:** From AI Playground to Deployment]($./M03 - Agent Evaluation and Deployment with Mosaic AI/3.1 - From AI Playground to Deployment)<br/>[**Lab:** Creating Tools and Testing in the Playground]($./M03 - Agent Evaluation and Deployment with Mosaic AI/3.2L - Creating Tools and Testing in the Playground) |
# | **[Module 4 – Production-ready Agents with Agent Bricks]($./M04 - Production-Ready Agents with Agent Bricks/)** | **Lecture -** Introduction to Agent Bricks<br/>[**Demo:** Build a Knowledge Assistant with Agent Bricks]($./M04 - Production-Ready Agents with Agent Bricks/4.1L - Build a Knowledge Assistant with Agent Bricks) |
#
# <br/>
#
# ---
#
# ## Requirements
#
# Please review the following requirements before starting the lesson:
#
# * To run demo and lab notebooks, you need to use the **`17.3.x-cpu-ml-scala2.13`**, which is enabled by default.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
